# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = 'https://raw.githubusercontent.com/S1mDu/LCA/main/Data/'

# %%
# Update the filepath to the local directory where the files are stored

demo = pd.read_excel(filepath + 'demography.xlsx')
#demo = pd.read_excel(demo_url)
tot = pd.read_excel(filepath + 'DR1TOT.xlsx')

# %%
df = pd.merge(demo, tot, how='outer', on='SEQN')
df.head()
# Out:
#      SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  130378        12         2         1        43       NaN         5
# 1  130379        12         2         1        66       NaN         3
# 2  130380        12         2         2        44       NaN         2
# 3  130381        12         2         2         5       NaN         5
# 4  130382        12         2         1         2       NaN         3
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DRD370QQ  DRD370R  DRD370RQ  DRD370S  \
# 0         6       2.0       NaN  ...       NaN      2.0       NaN      2.0
# 1         3       2.0       NaN  ...       1.0      2.0       NaN      2.0
# 2         2       1.0       NaN  ...       NaN      2.0       NaN      2.0
# 3         7       1.0      71.0  ...       NaN      2.0       NaN      2.0
# 4         3       2.0      34.0  ...       NaN      2.0       NaN      2.0
#
#    DRD370SQ  DRD370T  DRD370TQ  DRD370U  DRD370UQ  DRD370V
# ...

# %%
df.shape
# Out:
# (11933, 194)

# %%
df['INDFMPIR']
# Out:
# 0        5.00
# 1        5.00
# 2        1.41
# 3        1.53
# 4        3.60
#          ...
# 11928    2.01
# 11929     NaN
# 11930    1.95
# 11931    3.11
# 11932    5.00
# Name: INDFMPIR, Length: 11933, dtype: float64

# %%
df[df['INDFMPIR'] < 1.2].mean()
# Out:
# SEQN        136316.608521
# SDDSRVYR        12.000000
# RIDSTATR         1.762862
# RIAGENDR         1.555466
# RIDAGEYR        32.038585
#                 ...
# DRD370T          1.714506
# DRD370TQ         2.929730
# DRD370U          1.967593
# DRD370UQ         2.000000
# DRD370V          1.998457
# Length: 194, dtype: float64

# %%
macronutrient = ['DR1TKCAL', 'DR1TPROT', 'DR1TCARB', 'DR1TSUGR', 'DR1TFIBE', 'DR1TTFAT', 'DR1TSFAT', 'DR1TMFAT', 'DR1TPFAT']

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['INDFMPIR'], bins=5, color='blue', alpha=0.7)
plt.title('Distribution of INDFMPIR')
plt.xlabel('INDFMPIR')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
# Create 5 bins for INDFMPIR
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)
# Group by the bins and calculate the mean of DR1TKCAL
grouped = df.groupby(bins)['DR1TKCAL'].mean().reset_index()
# Rename the columns for clarity
grouped.columns = ['INDFMPIR_Bin', 'Mean_DR1TKCAL']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(grouped['INDFMPIR_Bin'], grouped['Mean_DR1TKCAL'], color='blue', alpha=0.7)
plt.title('Mean KCalories by INDFMPIR Bin')
plt.xlabel('INDFMPIR Bin')
plt.ylabel('Mean DR1TKCAL')
plt.xticks(grouped['INDFMPIR_Bin'], [f'Bin {i}' for i in grouped['INDFMPIR_Bin']])
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
# Create 5 bins for INDFMPIR
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)
# Group by the bins and calculate the mean of DR1TKCAL
grouped = df.groupby(bins)['DR1TPROT'].mean().reset_index()
# Rename the columns for clarity
grouped.columns = ['INDFMPIR_Bin', 'Mean_DR1TPROT']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(grouped['INDFMPIR_Bin'], grouped['Mean_DR1TPROT'], color='blue', alpha=0.7)
plt.title('Mean Protein by INDFMPIR Bin')
plt.xlabel('INDFMPIR Bin')
plt.ylabel('Mean DR1TPROT')
plt.xticks(grouped['INDFMPIR_Bin'], [f'Bin {i}' for i in grouped['INDFMPIR_Bin']])
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
macronutrient
# Out:
# ['DR1TKCAL',
#  'DR1TPROT',
#  'DR1TCARB',
#  'DR1TSUGR',
#  'DR1TFIBE',
#  'DR1TTFAT',
#  'DR1TSFAT',
#  'DR1TMFAT',
#  'DR1TPFAT']

# %%
# Create 5 bins for INDFMPIR
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)
# Group by the bins and calculate the mean of DR1TKCAL
grouped = df.groupby(bins)['DR1TTFAT'].mean().reset_index()
# Rename the columns for clarity
grouped.columns = ['INDFMPIR_Bin', 'Mean_DR1TTFAT']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(grouped['INDFMPIR_Bin'], grouped['Mean_DR1TTFAT'], color='blue', alpha=0.7)
plt.title('Mean Fats by INDFMPIR Bin')
plt.xlabel('INDFMPIR Bin')
plt.ylabel('Mean DR1TTFAT')
plt.xticks(grouped['INDFMPIR_Bin'], [f'Bin {i}' for i in grouped['INDFMPIR_Bin']])
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
# Create 5 bins for INDFMPIR
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)
# Group by the bins and calculate the mean of DR1TKCAL
grouped = df.groupby(bins)['DR1TSUGR'].mean().reset_index()
# Rename the columns for clarity
grouped.columns = ['INDFMPIR_Bin', 'Mean_DR1TSUGR']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(grouped['INDFMPIR_Bin'], grouped['Mean_DR1TSUGR'], color='blue', alpha=0.7)
plt.title('Mean Sugar by INDFMPIR Bin')
plt.xlabel('INDFMPIR Bin')
plt.ylabel('Mean DR1TSUGR')
plt.xticks(grouped['INDFMPIR_Bin'], [f'Bin {i}' for i in grouped['INDFMPIR_Bin']])
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
# Create 5 bins for INDFMPIR
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)
# Group by the bins and calculate the mean of DR1TKCAL
grouped = df.groupby(bins)['DR1TFIBE'].mean().reset_index()
# Rename the columns for clarity
grouped.columns = ['INDFMPIR_Bin', 'Mean_DR1TFIBE']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(grouped['INDFMPIR_Bin'], grouped['Mean_DR1TFIBE'], color='blue', alpha=0.7)
plt.title('Mean Fibers by INDFMPIR Bin')
plt.xlabel('INDFMPIR Bin')
plt.ylabel('Mean DR1TFIBE')
plt.xticks(grouped['INDFMPIR_Bin'], [f'Bin {i}' for i in grouped['INDFMPIR_Bin']])
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
# Create 5 bins for INDFMPIR
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)
# Group by the bins and calculate the mean of DR1TKCAL
grouped = df.groupby(bins)['DR1TSFAT'].mean().reset_index()
# Rename the columns for clarity
grouped.columns = ['INDFMPIR_Bin', 'Mean_DR1TSFAT']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(grouped['INDFMPIR_Bin'], grouped['Mean_DR1TSFAT'], color='blue', alpha=0.7)
plt.title('Mean Total Saturated Fats by INDFMPIR Bin')
plt.xlabel('INDFMPIR Bin')
plt.ylabel('Mean DR1TSFAT')
plt.xticks(grouped['INDFMPIR_Bin'], [f'Bin {i}' for i in grouped['INDFMPIR_Bin']])
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
macronutrient
# Out:
# ['DR1TKCAL',
#  'DR1TPROT',
#  'DR1TCARB',
#  'DR1TSUGR',
#  'DR1TFIBE',
#  'DR1TTFAT',
#  'DR1TSFAT',
#  'DR1TMFAT',
#  'DR1TPFAT']

# %%
# Create 5 bins for INDFMPIR
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)
# Group by the bins and calculate the mean of DR1TKCAL
grouped = df.groupby(bins)['DR1TMFAT'].mean().reset_index()
# Rename the columns for clarity
grouped.columns = ['INDFMPIR_Bin', 'Mean_DR1TMFAT']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(grouped['INDFMPIR_Bin'], grouped['Mean_DR1TMFAT'], color='blue', alpha=0.7)
plt.title('Mean MonoInsaturated Fats by INDFMPIR Bin')
plt.xlabel('INDFMPIR Bin')
plt.ylabel('Mean DR1TMFAT')
plt.xticks(grouped['INDFMPIR_Bin'], [f'Bin {i}' for i in grouped['INDFMPIR_Bin']])
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
# Create 5 bins for INDFMPIR
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)
# Group by the bins and calculate the mean of DR1TKCAL
grouped = df.groupby(bins)['DR1TPFAT'].mean().reset_index()
# Rename the columns for clarity
grouped.columns = ['INDFMPIR_Bin', 'Mean_DR1TPFAT']
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(grouped['INDFMPIR_Bin'], grouped['Mean_DR1TPFAT'], color='blue', alpha=0.7)
plt.title('Mean PolyInsaturated Fats by INDFMPIR Bin')
plt.xlabel('INDFMPIR Bin')
plt.ylabel('Mean DR1TMFAT')
plt.xticks(grouped['INDFMPIR_Bin'], [f'Bin {i}' for i in grouped['INDFMPIR_Bin']])
plt.grid(axis='y', alpha=0.25)
plt.show()

# %%
bins = pd.cut(df['INDFMPIR'], bins=4, labels=False)

# %%
bins.value_counts()
# Out:
# INDFMPIR
# 3.0    3207
# 0.0    2600
# 1.0    2368
# 2.0    1717
# Name: count, dtype: int64

# %%
grouped = df[df['DMDHRGND'] == 1].groupby(bins)[macronutrient].mean().reset_index()
# Rename the columns for clarity

# %%
grouped
# Out:
#    INDFMPIR     DR1TKCAL   DR1TPROT    DR1TCARB    DR1TSUGR   DR1TFIBE  \
# 0       0.0  1695.457831  60.152590  213.136988   99.445964  12.742771
# 1       1.0  1768.495413  59.476606  224.374495  101.660275  12.611468
# 2       2.0  1887.776923  62.129538  246.213231  114.669462  14.535385
# 3       3.0  1872.844444  64.575467  238.806533   98.197156  15.938667
#
#     DR1TTFAT   DR1TSFAT   DR1TMFAT   DR1TPFAT
# 0  67.983072  23.138855  22.349988  15.066711
# 1  71.455138  24.352514  22.903509  16.229890
# 2  73.346154  24.470223  24.202108  16.888354
# 3  74.661778  25.395413  24.607111  16.765960
